# %% [markdown]
# ## SDN Intrusion dataset - Data cleansing

# %% [markdown]
# ### The dataset contains 118833
# 3 rows × 80 columns.

# %%
#Import required packages
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Importing the SDN Intrusion Detection Dataset
df = pd.read_csv('/Users/sindhuvaddi/Downloads/SDN_Intrusion/0_Source_File/SDN_Intrusion.csv')

# %%
#Reading the dataset
df
# Out:
#          Unnamed: 0   Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 0                 80         9865922                   5
# 1                 1                443          158423                  24
# 2                 2                443        61163904                  14
# 3                 3                443       110544045                  18
# 4                 4                 53             185                   2
# ...             ...                ...             ...                 ...
# 1188328     1188328                138              23                  13
# 1188329     1188329              50898         7188897                   1
# 1188330     1188330                 53             153                   2
# 1188331     1188331                 80         1868954                   6
# 1188332     1188332                 80       109749628                   5
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# ...

# %% [markdown]
# #### Replacing spaces with '_' for better readability

# %%
df.columns = [c.replace(' ', '', 1) for c in df.columns]
df.columns = [c.replace(' ', '_') for c in df.columns]
df
# Out:
#          Unnamed:0  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                0                80        9865922                  5
# 1                1               443         158423                 24
# 2                2               443       61163904                 14
# 3                3               443      110544045                 18
# 4                4                53            185                  2
# ...            ...               ...            ...                ...
# 1188328    1188328               138             23                 13
# 1188329    1188329             50898        7188897                  1
# 1188330    1188330                53            153                  2
# 1188331    1188331                80        1868954                  6
# 1188332    1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# ...

# %% [markdown]
# #### Droping null values present in the dataset

# %%
df = df.dropna(axis =0)
df
# Out:
#          Unnamed:0  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                0                80        9865922                  5
# 1                1               443         158423                 24
# 2                2               443       61163904                 14
# 3                3               443      110544045                 18
# 4                4                53            185                  2
# ...            ...               ...            ...                ...
# 1188328    1188328               138             23                 13
# 1188329    1188329             50898        7188897                  1
# 1188330    1188330                53            153                  2
# 1188331    1188331                80        1868954                  6
# 1188332    1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# ...

# %%
col1 = df.columns[0]
col1
# Out:
# 'Unnamed:0'

# %%
col2 = df.columns[7:9]
col2
# Out:
# Index(['Fwd_Packet_Length_Max', 'Fwd_Packet_Length_Min'], dtype='object')

# %%
col3 = df.columns[10:13]
col3
# Out:
# Index(['Fwd_Packet_Length_Std', 'BwdPacket_Length_Max',
#        'Bwd_Packet_Length_Min'],
#       dtype='object')

# %%
col4 = df.columns[14]
col4
# Out:
# 'Bwd_Packet_Length_Std'

# %%
col5 = df.columns[17:37]
col5
# Out:
# Index(['Flow_IAT_Mean', 'Flow_IAT_Std', 'Flow_IAT_Max', 'Flow_IAT_Min',
#        'FwdIAT_Total', 'Fwd_IAT_Mean', 'Fwd_IAT_Std', 'Fwd_IAT_Max',
#        'Fwd_IAT_Min', 'BwdIAT_Total', 'Bwd_IAT_Mean', 'Bwd_IAT_Std',
#        'Bwd_IAT_Max', 'Bwd_IAT_Min', 'FwdPSH_Flags', 'Bwd_PSH_Flags',
#        'Fwd_URG_Flags', 'Bwd_URG_Flags', 'Fwd_Header_Length',
#        'Bwd_Header_Length'],
#       dtype='object')

# %%
col6 = df.columns[39:41]
col6
# Out:
# Index(['Min_Packet_Length', 'Max_Packet_Length'], dtype='object')

# %%
col7 = df.columns[42:44]
col7
# Out:
# Index(['Packet_Length_Std', 'Packet_Length_Variance'], dtype='object')

# %%
col8 = df.columns[46:48]
col8
# Out:
# Index(['RST_Flag_Count', 'PSH_Flag_Count'], dtype='object')

# %%
col9 = df.columns[54:63]
col9
# Out:
# Index(['Avg_Fwd_Segment_Size', 'Avg_Bwd_Segment_Size', 'Fwd_Header_Length.1',
#        'FwdAvg_Bytes/Bulk', 'Fwd_Avg_Packets/Bulk', 'Fwd_Avg_Bulk_Rate',
#        'Bwd_Avg_Bytes/Bulk', 'Bwd_Avg_Packets/Bulk', 'BwdAvg_Bulk_Rate'],
#       dtype='object')

# %%
col10 = df.columns[67:71]
col10
# Out:
# Index(['Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward'],
#       dtype='object')

# %%
col11 = df.columns[72:75]
col11
# Out:
# Index(['Active_Std', 'Active_Max', 'Active_Min'], dtype='object')

# %%
col12 = df.columns[76:79]
col12
# Out:
# Index(['Idle_Std', 'Idle_Max', 'Idle_Min'], dtype='object')

# %% [markdown]
# #### Droping columns that are not required

# %%
df = df.drop(columns = col1)
df = df.drop(columns = col2)
df = df.drop(columns = col3)
df = df.drop(columns = col4)
df = df.drop(columns = col5)
df = df.drop(columns = col6)
df = df.drop(columns = col7)
df = df.drop(columns = col8)
df = df.drop(columns = col9)
df = df.drop(columns = col10)
df = df.drop(columns = col11)
df = df.drop(columns = col12)
df
# Out:
#          Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                      80        9865922                  5
# 1                     443         158423                 24
# 2                     443       61163904                 14
# 3                     443      110544045                 18
# 4                      53            185                  2
# ...                   ...            ...                ...
# 1188328               138             23                 13
# 1188329             50898        7188897                  1
# 1188330                53            153                  2
# 1188331                80        1868954                  6
# 1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# 0                             0                          30
# 1                            22                         703
# 2                            12                         993
# ...

# %% [markdown]
# #### Rounding a decimal number to two decimal places for better readability

# %%
df = df.round(decimals=2)
df
# Out:
#          Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                      80        9865922                  5
# 1                     443         158423                 24
# 2                     443       61163904                 14
# 3                     443      110544045                 18
# 4                      53            185                  2
# ...                   ...            ...                ...
# 1188328               138             23                 13
# 1188329             50898        7188897                  1
# 1188330                53            153                  2
# 1188331                80        1868954                  6
# 1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# 0                             0                          30
# 1                            22                         703
# 2                            12                         993
# ...

# %%
#Displaying the Data Types of each Column
df.dtypes
# Out:
# Destination_Port                 int64
# Flow_Duration                    int64
# Total_Fwd_Packets                int64
# Total_Backward_Packets           int64
# TotalLength_of_Fwd_Packets       int64
# Total_Length_of_Bwd_Packets      int64
# Fwd_Packet_Length_Mean         float64
# Bwd_Packet_Length_Mean         float64
# FlowBytes/s                    float64
# Flow_Packets/s                 float64
# FwdPackets/s                   float64
# Bwd_Packets/s                  float64
# Packet_Length_Mean             float64
# FINFlag_Count                    int64
# SYN_Flag_Count                   int64
# ACK_Flag_Count                   int64
# URG_Flag_Count                   int64
# CWE_Flag_Count                   int64
# ECE_Flag_Count                   int64
# Down/Up_Ratio                    int64
# Average_Packet_Size            float64
# SubflowFwd_Packets               int64
# Subflow_Fwd_Bytes                int64
# Subflow_Bwd_Packets              int64
# ...

# %% [markdown]
# #### Removing '�' from Class column

# %%
df['Class'] = df['Class'].str.replace('�','')
df
# Out:
#          Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                      80        9865922                  5
# 1                     443         158423                 24
# 2                     443       61163904                 14
# 3                     443      110544045                 18
# 4                      53            185                  2
# ...                   ...            ...                ...
# 1188328               138             23                 13
# 1188329             50898        7188897                  1
# 1188330                53            153                  2
# 1188331                80        1868954                  6
# 1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# 0                             0                          30
# 1                            22                         703
# 2                            12                         993
# ...

# %% [markdown]
# #### Removing negative values that exist from different columns

# %%
df = df[df['Flow_Duration']!= -1]
df
# Out:
#          Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                      80        9865922                  5
# 1                     443         158423                 24
# 2                     443       61163904                 14
# 3                     443      110544045                 18
# 4                      53            185                  2
# ...                   ...            ...                ...
# 1188328               138             23                 13
# 1188329             50898        7188897                  1
# 1188330                53            153                  2
# 1188331                80        1868954                  6
# 1188332                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# 0                             0                          30
# 1                            22                         703
# 2                            12                         993
# ...

# %% [markdown]
# #### Introduce a new column for the purpose of Indexing

# %%
df.insert(0,"Intrusion_Id", np.arange(1,len(df)+1))
df
# Out:
#          Intrusion_Id  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                   1                80        9865922                  5
# 1                   2               443         158423                 24
# 2                   3               443       61163904                 14
# 3                   4               443      110544045                 18
# 4                   5                53            185                  2
# ...               ...               ...            ...                ...
# 1188328       1188221               138             23                 13
# 1188329       1188222             50898        7188897                  1
# 1188330       1188223                53            153                  2
# 1188331       1188224                80        1868954                  6
# 1188332       1188225                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# ...

# %% [markdown]
# #### Renaming some column names for better readability

# %%
df.rename(columns={'FlowBytes/s': 'FlowBytes_s', 'Flow_Packets/s': 'Flow_Packets_s', 'FwdPackets/s': 'FwdPackets_s', 'Bwd_Packets/s': 'Bwd_Packets_s','Down/Up_Ratio': 'Down_Up_Ratio'}, inplace = True)
df
# Out:
# /Users/sindhuvaddi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#          Intrusion_Id  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                   1                80        9865922                  5
# 1                   2               443         158423                 24
# 2                   3               443       61163904                 14
# 3                   4               443      110544045                 18
# 4                   5                53            185                  2
# ...               ...               ...            ...                ...
# 1188328       1188221               138             23                 13
# ...

# %% [markdown]
# #### Checking the new column names

# %%
df.columns
# Out:
# Index(['Intrusion_Id', 'Destination_Port', 'Flow_Duration',
#        'Total_Fwd_Packets', 'Total_Backward_Packets',
#        'TotalLength_of_Fwd_Packets', 'Total_Length_of_Bwd_Packets',
#        'Fwd_Packet_Length_Mean', 'Bwd_Packet_Length_Mean', 'FlowBytes_s',
#        'Flow_Packets_s', 'FwdPackets_s', 'Bwd_Packets_s', 'Packet_Length_Mean',
#        'FINFlag_Count', 'SYN_Flag_Count', 'ACK_Flag_Count', 'URG_Flag_Count',
#        'CWE_Flag_Count', 'ECE_Flag_Count', 'Down_Up_Ratio',
#        'Average_Packet_Size', 'SubflowFwd_Packets', 'Subflow_Fwd_Bytes',
#        'Subflow_Bwd_Packets', 'Subflow_Bwd_Bytes', 'ActiveMean', 'IdleMean',
#        'Class'],
#       dtype='object')

# %% [markdown]
# #### Checking for correaltion between the variables

# %%
df.corr()
# Out:
#                              Intrusion_Id  Destination_Port  Flow_Duration  \
# Intrusion_Id                     1.000000         -0.000627       0.000539
# Destination_Port                -0.000627          1.000000      -0.000882
# Flow_Duration                    0.000539         -0.000882       1.000000
# Total_Fwd_Packets               -0.000175         -0.003984       0.022554
# Total_Backward_Packets          -0.000139         -0.003256       0.021560
# TotalLength_of_Fwd_Packets      -0.000023          0.176633       0.159072
# Total_Length_of_Bwd_Packets     -0.000255         -0.003394       0.017571
# Fwd_Packet_Length_Mean          -0.000404          0.497007       0.211429
# Bwd_Packet_Length_Mean          -0.000554         -0.266000       0.186984
# FlowBytes_s                      0.000834          0.043860      -0.021471
# Flow_Packets_s                   0.000115          0.228916      -0.084429
# ...

# %%
df.describe()
# Out:
#        Intrusion_Id  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# count  1.188225e+06      1.188225e+06   1.188225e+06       1.188225e+06
# mean   5.941130e+05      8.479059e+03   1.462313e+07       9.596966e+00
# std    3.430112e+05      1.914970e+04   3.176123e+07       7.448564e+02
# min    1.000000e+00      0.000000e+00   0.000000e+00       1.000000e+00
# 25%    2.970570e+05      5.300000e+01   1.683500e+04       2.000000e+00
# 50%    5.941130e+05      8.000000e+01   2.795230e+05       3.000000e+00
# 75%    8.911690e+05      4.430000e+02   6.103905e+06       5.000000e+00
# max    1.188225e+06      6.553200e+04   1.200000e+08       2.007550e+05
#
#        Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# count            1.188225e+06                1.188225e+06
# mean             1.078194e+01                7.843723e+02
# std              9.896532e+02                5.758409e+03
# min              0.000000e+00                0.000000e+00
# ...

# %% [markdown]
# #### Exporting the clean dataframe into csv file

# %%
df.to_csv("/Users/sindhuvaddi/Downloads/SDN_Intrusion/5_Database_Creation_and_load/Cleansed_SDN_Intrusion.csv")

# %%
df
# Out:
#          Intrusion_Id  Destination_Port  Flow_Duration  Total_Fwd_Packets  \
# 0                   1                80        9865922                  5
# 1                   2               443         158423                 24
# 2                   3               443       61163904                 14
# 3                   4               443      110544045                 18
# 4                   5                53            185                  2
# ...               ...               ...            ...                ...
# 1188328       1188221               138             23                 13
# 1188329       1188222             50898        7188897                  1
# 1188330       1188223                53            153                  2
# 1188331       1188224                80        1868954                  6
# 1188332       1188225                80      109749628                  5
#
#          Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# ...

# %% [markdown]
# ### The dataset is clean and ready to be imported into Neo4j database.
