# %% [markdown]
# Data Validation

# %%
#Import Matplotlib, Seaborn and Pandas packages
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns   
import pandas as pd

# %%
#Importing the SDN Intrusion Detection File after data cleansing

df = pd.read_csv('/Users/sindhuvaddi/Downloads/SDN_Intrusion/5_Database_Creation_and_load/Cleansed_SDN_intrusion.csv')

# %%
#Displaying the top 5 rows of data
df.head(10)
# Out:
#    Unnamed: 0  Intrusion_Id  Destination_Port  Flow_Duration  \
# 0           0             1                80        9865922
# 1           1             2               443         158423
# 2           2             3               443       61163904
# 3           3             4               443      110544045
# 4           4             5                53            185
# 5           5             6                53            672
# 6           6             7             51323         490655
# 7           7             8                53         163154
# 8           8             9                80        1875517
# 9           9            10                53          23800
#
#    Total_Fwd_Packets  Total_Backward_Packets  TotalLength_of_Fwd_Packets  \
# 0                  5                       0                          30
# 1                 24                      22                         703
# ...

# %%
#Showing a Data Sample from the Dataset

sample_dataset = df.sample(n = 25)
sample_dataset
# Out:
#          Unnamed: 0  Intrusion_Id  Destination_Port  Flow_Duration  \
# 18009         18010         18010                80       95895192
# 162870       162886        162871                80        1429987
# 575191       575242        575192               123          27754
# 1008418     1008515       1008419                80        1068109
# 305911       305942        305912                80        1516373
# 901220       901303        901221                80       63657607
# 385851       385885        385852             60850             60
# 1079299     1079400       1079300                53            162
# 1027438     1027537       1027439                53          27159
# 1017219     1017318       1017220                53            241
# 719854       719921        719855             35969        3688554
# 188436       188453        188437             52971             64
# 248636       248659        248637             49667          53664
# ...

# %%
#Validating the Data Format
df.dtypes
# Out:
# Unnamed: 0                       int64
# Intrusion_Id                     int64
# Destination_Port                 int64
# Flow_Duration                    int64
# Total_Fwd_Packets                int64
# Total_Backward_Packets           int64
# TotalLength_of_Fwd_Packets       int64
# Total_Length_of_Bwd_Packets      int64
# Fwd_Packet_Length_Mean         float64
# Bwd_Packet_Length_Mean         float64
# FlowBytes_s                    float64
# Flow_Packets_s                 float64
# FwdPackets_s                   float64
# Bwd_Packets_s                  float64
# Packet_Length_Mean             float64
# FINFlag_Count                    int64
# SYN_Flag_Count                   int64
# ACK_Flag_Count                   int64
# URG_Flag_Count                   int64
# CWE_Flag_Count                   int64
# ECE_Flag_Count                   int64
# Down_Up_Ratio                    int64
# Average_Packet_Size            float64
# SubflowFwd_Packets               int64
# ...

# %%
#Complete list of Attributes along with their Data Type, Non-Null fields. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188225 entries, 0 to 1188224
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Unnamed: 0                   1188225 non-null  int64
#  1   Intrusion_Id                 1188225 non-null  int64
#  2   Destination_Port             1188225 non-null  int64
#  3   Flow_Duration                1188225 non-null  int64
#  4   Total_Fwd_Packets            1188225 non-null  int64
#  5   Total_Backward_Packets       1188225 non-null  int64
#  6   TotalLength_of_Fwd_Packets   1188225 non-null  int64
#  7   Total_Length_of_Bwd_Packets  1188225 non-null  int64
#  8   Fwd_Packet_Length_Mean       1188225 non-null  float64
#  9   Bwd_Packet_Length_Mean       1188225 non-null  float64
#  10  FlowBytes_s                  1188225 non-null  float64
#  11  Flow_Packets_s               1188225 non-null  float64
# ...

# %%
#Checking null values
df.isnull().sum()
# Out:
# Unnamed: 0                     0
# Intrusion_Id                   0
# Destination_Port               0
# Flow_Duration                  0
# Total_Fwd_Packets              0
# Total_Backward_Packets         0
# TotalLength_of_Fwd_Packets     0
# Total_Length_of_Bwd_Packets    0
# Fwd_Packet_Length_Mean         0
# Bwd_Packet_Length_Mean         0
# FlowBytes_s                    0
# Flow_Packets_s                 0
# FwdPackets_s                   0
# Bwd_Packets_s                  0
# Packet_Length_Mean             0
# FINFlag_Count                  0
# SYN_Flag_Count                 0
# ACK_Flag_Count                 0
# URG_Flag_Count                 0
# CWE_Flag_Count                 0
# ECE_Flag_Count                 0
# Down_Up_Ratio                  0
# Average_Packet_Size            0
# SubflowFwd_Packets             0
# Subflow_Fwd_Bytes              0
# Subflow_Bwd_Packets            0
# Subflow_Bwd_Bytes              0
# ActiveMean                     0
# ...

# %%
#Importing the Original data file before cleaing 
Original_df = pd.read_csv('/Users/sindhuvaddi/Downloads/SDN_Intrusion/0_Source_File/SDN_Intrusion.csv')
Original_df.head(10)
# Out:
#    Unnamed: 0   Destination Port   Flow Duration   Total Fwd Packets  \
# 0           0                 80         9865922                   5
# 1           1                443          158423                  24
# 2           2                443        61163904                  14
# 3           3                443       110544045                  18
# 4           4                 53             185                   2
# 5           5                 53             672                   1
# 6           6              51323          490655                   6
# 7           7                 53          163154                   2
# 8           8                 80         1875517                   3
# 9           9                 53           23800                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           30
# 1                       22                          703
# ...

# %%
#Comparing the count of Rows and Columns from both datasets

#Original Dataset
print('The number of Rows and Columns in the Original file:',Original_df.shape)

#Dataset after cleaning
print('The number of Rows and Columns after Data Cleaning:', df.shape)
# Out:
# The number of Rows and Columns in the Original file: (1188333, 80)
# The number of Rows and Columns after Data Cleaning: (1188225, 30)
